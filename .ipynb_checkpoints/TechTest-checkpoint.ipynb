# %% [markdown]
# Charlotte Hill

# %% [markdown]
# Standard imports for data analysis and plotting.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1 - Calibration

# %% [markdown]
# Read in the calibration data - skipping over the info at the head of the CSV file.

# %%
calib = pd.read_csv("calibration.csv", header=10)

# %% [markdown]
# Separate the two samples (this makes the indexing a lot simpler!). We can also drop the columns we're not interested in.

# %%
S1 = calib.loc[calib.Sample == 'S1'].drop(columns=['Well','Sample'])
Blank = calib.loc[calib.Sample == 'Blank'].drop(columns=['Well','Sample','Dilution'])

# %% [markdown]
# To plot, calculate the mean (y-value) and its standard error $\frac{\sigma}{\sqrt{N}}$ (y-error) for each triplicate measurement.

# %%
S1_mean = S1.groupby('Dilution').mean()
S1_err = S1.groupby('Dilution').std()/np.sqrt(3)
B_mean = Blank.mean()
B_err = Blank.std()/np.sqrt(3)
x = S1.columns.values[1:].astype('int')

# %% [markdown]
# Plot the data (with errors).

# %%
plt.figure(figsize=(10,6))
for i in range(len(S1_mean)):
    plt.plot(x, S1_mean.iloc[i], label=S1_mean.iloc[i].name)
    plt.fill_between(x, (S1_mean-S1_err).iloc[i], (S1_mean+S1_err).iloc[i], alpha=0.5)
plt.plot(x, B_mean, label='Blank')
plt.fill_between(x, (B_mean-B_err), (B_mean+B_err), alpha=0.5)
plt.xlabel('$\lambda$ (nm)')
plt.ylabel('Absorbance')
plt.legend(title='Dilution')
plt.title("Absorbance (Raw) vs Wavelength")
plt.show()

# %% [markdown]
# Given that the absorbance of a sample $x$ is $A_x = \sum_i A_{x_i}$ for all constituent compounds $x_i$, to correct for the solvent, simply subtract the absorbance of the blank sample.

# %%
corr_mean = S1_mean-B_mean
corr_err = S1_err+B_err

# %%
plt.figure(figsize=(10,6))
for i in range(len(corr_mean)):
    plt.plot(x, corr_mean.iloc[i], label=corr_mean.iloc[i].name)
    plt.fill_between(x, (corr_mean-corr_err).iloc[i], (corr_mean+corr_err).iloc[i], alpha=0.5)
plt.xlabel('$\lambda$ (nm)')
plt.ylabel('Absorbance')
plt.legend(title='Dilution')
plt.title("Absorbance (Blank Corrected) vs Wavelength")
plt.show()

# %% [markdown]
# Area of greatest interest

# %%
plt.figure(figsize=(10,6))
for i in range(len(corr_mean)):
    plt.plot(x, corr_mean.iloc[i], label=corr_mean.iloc[i].name)
    plt.fill_between(x, (corr_mean-corr_err).iloc[i], (corr_mean+corr_err).iloc[i], alpha=0.5)
plt.xlabel('$\lambda$ (nm)')
plt.ylabel('Absorbance')
plt.xlim(450., 600.)
plt.ylim(-0.1, 1.8)
plt.legend(title='Dilution')
plt.title("Absorbance (Blank Corrected) vs Wavelength")
plt.show()

# %% [markdown]
# ## Part 2 - Calculation

# %% [markdown]
# Recall:
# $A(\lambda,c) = E(\lambda)lc$.

# %% [markdown]
# Then, for a given wavelength $\lambda_0$, define $A(c\,|\,\lambda_0) = E_0lc$.

# %% [markdown]
# Since $l$ is constant (1cm) across all the data, we can rewrite this as $A = \alpha c$.

# %% [markdown]
# For a dilution $D$, the concentration $c$ in mgL$^{-1}$ is given by $c = 50 D^{-1}$.

# %%
plt.figure(figsize=(10,6))
for i in range(len(corr_mean)):
    plt.plot(x, corr_mean.iloc[i], label=corr_mean.iloc[i].name)
    plt.vline(530, label='\lamdba_0')
plt.xlabel('$\lambda$ (nm)')
plt.ylabel('Absorbance')
plt.xlim(450., 600.)
plt.ylim(-0.1, 1.8)
plt.legend(title='Dilution')
plt.title("Absorbance (Blank Corrected) vs Wavelength")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-144-abb3e7014592> in <module>
#       1 plt.figure(figsize=(10,6))
#       2 for i in range(len(corr_mean)):
# ----> 3     plt.plot(x, corr_mean.iloc[i], label=corr_mean.iloc[i].name)
#       4     plt.vline(530, label='\lamdba_0')
#       5 plt.xlabel('$\lambda$ (nm)')
#
# c:\python39\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# c:\python39\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
# ...

# %%
for i in range (len(C)):
    plt.scatter(x, A[i]/C[i])
    plt.ylim(-0.1,0.1)
    plt.xlim(400,600)

# %%
C
# Out:
# array([50.      , 25.      , 12.5     ,  6.25    ,  3.125   ,  1.5625  ,
#         0.78125 ,  0.390625])
